# %%
from main1 import remove_stopwords, load_stopwords, get_term_freq, main #import all functions

# %% [markdown]
# ### First we have a function that loads all of the stopwords into a set

# %%
stopwords = load_stopwords("stopwords.txt")
print(stopwords)

# %% [markdown]
# ### Once we have that we can read the text and remove unwanted stop words

# %%
words_a = remove_stopwords("textA.txt", stopwords)
words_b = remove_stopwords("textB.txt", stopwords)

print(words_a[0:5]) #Print 5 example elements

# %%
# This function creates a dictionary of each remaining word minus the stopwords, and the number
# of times wach word appears

# It then takes the dictionary and makes a new one with the term frequency (proportion of each word
# to the total number of words in the file)
